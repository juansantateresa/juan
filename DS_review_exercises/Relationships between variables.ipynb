# %% [markdown]
# In this notebook, we will explore how proceed in order to find quickly relationships between variables using plots, and seeing what can we found over them

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# We are going to use the Australian Weather dataset. Let's read and briefly explore it

# %%
weather = pd.read_csv('/Users/juansantateresagomez/Desktop/small_DS_exercises/juan/DS_review_exercises/weatherAUS.csv')

# %%
weather.info
# Out:
# <bound method DataFrame.info of               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
weather.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
MinTemp = weather['MinTemp']
MaxTemp = weather['MaxTemp']

# %% [markdown]
# Accordingly, using plt.scatter, we are going to find if there is any relation between MinTemp and MaxTemp either weak or strong

# %%
plt.scatter(MinTemp, MaxTemp, marker=".")

# %% [markdown]
# Here we have a strong positive relationship

# %%
Humidity9am = weather['Humidity9am']

# %%
plt.scatter(MaxTemp, Humidity9am, marker = ",")

# %% [markdown]
# Here is a strong negative position

# %%
Humidity3am = weather['Humidity3pm']

# %%
plt.scatter(MinTemp, Humidity3am, marker = '.')
plt.show()

# %% [markdown]
# In this last example there is no apparent relationship
